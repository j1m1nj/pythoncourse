# %% [markdown]
# %%writefile app.py
# # 20230282 윤지민
# # app.py - 윤지민의 독서 기록 앱
# print("안녕하세요, 저는 윤지민입니다.")
# print("제가 만들 앱은 독서 기록 앱입니다.")

# %%
# %run app.py
# Out:
# 안녕하세요, 저는 윤지민입니다.
# 제가 만들 앱은 독서 기록 앱입니다.
